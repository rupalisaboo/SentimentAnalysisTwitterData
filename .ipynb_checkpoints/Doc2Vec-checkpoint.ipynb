# %%
import time
from timeit import default_timer
from contextlib import contextmanager

@contextmanager
def elapsed_timer():
    start = default_timer()
    print 'I\'m here.' + time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime())
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start
    print 'I\'m done.' + time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime())

# %%
with elapsed_timer() as elapsed:
    time.sleep(1)
    duration = '%.1f' % elapsed()
    print duration
    time.sleep(4)
# Out:
# I'm here.2015-12-09 12:47:26
# 1.0
# I'm done.2015-12-09 12:47:31

# %%
# %%bash
# #Split the all_views, get one file(sentiment, tweet) for each view
# #Clean each view
# #Run this for each view.
# norm() {
#     fn=$1
#     if [ ! -f "$fn" ]
#     then
#         echo "File: $fn not found"
#         exit
#     fi
#     #this function will convert text to lowercase and will disconnect punctuation and special symbols from words
#     function normalize_text {
#         awk '{print tolower($0);}' < $1 | sed -e 's/\./ \. /g' -e 's/<br \/>/ /g' -e 's/"/ " /g' \
#         -e 's/,/ , /g' -e 's/(/ ( /g' -e 's/)/ ) /g' -e 's/\!/ \! /g' -e 's/\?/ \? /g' \
#         -e 's/\;/ \; /g' -e 's/\:/ \: /g' > $1-norm
#     }
#     export LC_ALL=C
#     normalize_text "$fn"
#     wc -l $fn
#     mv "$fn" "$fn-norm"
# }
# norm "data/tweet_view1_clean" #file name is
# norm "data/tweet_view2_clean"
# Out:
# File: data/tweet_view1_clean not found

# %%
import os.path
tw_view_1 = 'data/tweet_view1_clean-norm'
tw_view_2 = 'data/tweet_view2_clean-norm'
assert os.path.isfile(tw_view_1), tw_view_1 + " unavailable"
assert os.path.isfile(tw_view_2), tw_view_2 + " unavailable"

# %%
# VIEW 1

# %%
import gensim
import numpy as np
from gensim.models.doc2vec import TaggedDocument
from collections import namedtuple, defaultdict as dd

#sentiment = {'positive':1, 'negative':-1} #, 'neutral':2}
sentiment_dict = {'4':1, '0':-1} #- new data 0,4
SentimentDocument = namedtuple('SentimentDocument', 'words tags split sentiment')

alldocs = dd(list)  # will hold all docs in original order - dictionary, keys = [v1, v2]
v1 = 'view1'
v2 = 'view2'
#tw_sentiment_dict = {}
#print total_num, train_test_shuffle
all_v2_words = []
with open(tw_view_2) as allview2:
        all_v2_words = allview2.readlines()
total_num = len(all_v2_words)
#split train/test
train_num = total_num *  7 / 10 # 70% train/test
train_test_shuffle = np.arange(total_num)
np.random.shuffle(train_test_shuffle)
with open(tw_view_1) as allview1:
    #for line_no, (v1, v2) in enumerate(zip(allview1, allview2)):
    for line_no, line in enumerate(allview1):
        tokens = gensim.utils.to_unicode(line).split('\t')
        if len(tokens) != 2:
            print line
            raise Exception()
        sentiment = sentiment_dict[tokens[0]]
        #if tw_id not in tw_sentiment_dict.keys():
        #    continue
        words = tokens[1]
        split = 'train' if train_test_shuffle[line_no] <= train_num else 'test'
        #sentiment = tw_sentiment_dict[tw_id]
        v2_words = gensim.utils.to_unicode(all_v2_words[line_no]).split('\t')[1]
        
        alldocs[v1].append(SentimentDocument(words, [line_no], split, sentiment))
        alldocs[v2].append(SentimentDocument(v2_words, [line_no], split, sentiment))
train_docs = {
    v1 : [doc for doc in alldocs[v1] if doc.split == 'train'],
    v2 : [doc for doc in alldocs[v2] if doc.split == 'train']
}
test_docs = {
    v1 : [doc for doc in alldocs[v1] if doc.split == 'test'],
    v2 : [doc for doc in alldocs[v2] if doc.split == 'test']
}
doc_list = { v1: alldocs[v1][:], v2: alldocs[v2][:] }  # for reshuffling per pass

print('%d docs: %d train-sentiment, %d test-sentiment' % (len(doc_list[v1]), len(train_docs[v1]), len(test_docs[v1])))
# Out:
# 295 docs: 207 train-sentiment, 88 test-sentiment

# %%
from gensim.models import Doc2Vec
import gensim.models.doc2vec
from collections import OrderedDict
import multiprocessing

cores = multiprocessing.cpu_count()
assert gensim.models.doc2vec.FAST_VERSION > -1, "this will be painfully slow otherwise"
model_size = 100
simple_models , models_by_name = {}, {} 
for view in [v1, v2]:
    simple_models[view] = [
        # PV-DM w/concatenation - window=5 (both sides) approximates paper's 10-word total window size
        Doc2Vec(dm=1, dm_concat=1, size=model_size, window=3, negative=5, hs=0, min_count=2, workers=cores),
        # PV-DBOW 
        Doc2Vec(dm=0, size=model_size, negative=5, hs=0, min_count=5, workers=cores),
        # PV-DM w/average
        Doc2Vec(dm=1, dm_mean=1, size=model_size, window=3, negative=5, hs=0, min_count=2, workers=cores),
    ]

    # speed setup by sharing results of 1st model's vocabulary scan
    simple_models[view][0].build_vocab(alldocs[view])  # PV-DM/concat requires one special NULL word so it serves as template
    print view, simple_models[view][0]
    for model in simple_models[view][1:]:
        model.reset_from(simple_models[view][0])
        print view, model

    models_by_name[view] = OrderedDict((str(model), model) for model in simple_models[view])
# Out:
# view1 Doc2Vec(dm/c,d100,n5,w3,mc5,t4)
# view1 Doc2Vec(dbow,d100,n5,mc5,t4)
# view1 Doc2Vec(dm/m,d100,n5,w3,mc2,t4)
# view2 Doc2Vec(dm/c,d100,n5,w3,mc5,t4)
# view2 Doc2Vec(dbow,d100,n5,mc5,t4)
# view2 Doc2Vec(dm/m,d100,n5,w3,mc2,t4)

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec
for view in [v1, v2]:
    models_by_name[view]['dbow+dmm'] = ConcatenatedDoc2Vec([simple_models[view][1], simple_models[view][2]])
    models_by_name[view]['dbow+dmc'] = ConcatenatedDoc2Vec([simple_models[view][1], simple_models[view][0]])
#print models_by_name['dbow+dmm'], models_by_name['dbow+dmc'] 
#del models_by_name['dbow+dmc']

# %%
import numpy as np
import statsmodels.api as sm
from sklearn import svm, metrics
from random import sample

# for timing
from contextlib import contextmanager
from timeit import default_timer
import time 
import ipdb

@contextmanager
def elapsed_timer():
    start = default_timer()
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start
    
def logistic_predictor_from_data(train_targets, train_regressors):
    logit = sm.Logit(train_targets, train_regressors)
    #ipdb.set_trace()
    predictor = logit.fit(disp=0)
    #print(predictor.summary())
    return predictor

def svm_predictor_from_data(train_targets, train_regressors):
    svc = svm.SVC(kernel='rbf', degree=5, gamma=1.0, C=2.5)
    svc.fit(train_regressors, train_targets)
    return svc

    """expected = svm_y_test
    predicted = svc.predict(svm_x_test)

    #print("Classification report for classifier %s:\n%s\n"
    #      % (svc, metrics.classification_report(expected, predicted)))
    #print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))
    """

def error_rate_for_model(test_model, train_set, test_set, infer=False, infer_steps=3, infer_alpha=0.1, infer_subsample=0.1):
    """Report error rate on test_doc sentiments, using supplied model and train_docs"""

    train_targets, train_regressors = zip(*[(doc.sentiment, test_model.docvecs[doc.tags[0]]) for doc in train_set])
    #train_regressors = sm.add_constant(train_regressors)
    #predictor = logistic_predictor_from_data(train_targets, train_regressors)
    predictor = svm_predictor_from_data(train_targets, train_regressors)

    test_data = test_set
    if infer:
        if infer_subsample < 1.0:
            test_data = sample(test_data, int(infer_subsample * len(test_data)))
        test_regressors = [test_model.infer_vector(doc.words, steps=infer_steps, alpha=infer_alpha) for doc in test_data]
    else:
        test_regressors = [test_model.docvecs[doc.tags[0]] for doc in test_data]
    #test_regressors = sm.add_constant(test_regressors)
    
    # predict & evaluate
    test_predictions = predictor.predict(test_regressors)
    predicted = np.rint(test_predictions)
    expected = [doc.sentiment for doc in test_data]
    """if not infer:
        print("Classification report for classifier %s:\n%s\n"
              % (predictor, metrics.classification_report(expected, predicted)))
        print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))"""
    #ipdb.set_trace()
    corrects = sum(expected == predicted)
    errors = len(test_predictions) - corrects
    error_rate = float(errors) / len(test_predictions)
    return (error_rate, errors, len(test_predictions), predictor)

# %%
#from collections import defaultdict
best_error = dd(lambda: dd(lambda :(1.0, 0.0)))  # to selectively-print only best errors achieved

# %%
print 'Started.'
from random import shuffle
import datetime

for view in [v1, v2]:
    alpha, min_alpha, passes = (0.025, 0.001, 20)
    alpha_delta = (alpha - min_alpha) / passes

    print "======== %s =========" %view
    print("START %s" % datetime.datetime.now())

    for epoch in range(passes):
        shuffle(doc_list[view])  # shuffling gets best results

        for name, train_model in models_by_name[view].items():
            #print name
            # train
            duration = 'na'
            train_model.alpha, train_model.min_alpha = alpha, alpha
            with elapsed_timer() as elapsed:
                train_model.train(doc_list[view])
                duration = '%.1f' % elapsed()

            # evaluate
            eval_duration = ''
            with elapsed_timer() as eval_elapsed:
                err, err_count, test_count, predictor = error_rate_for_model(train_model, train_docs[view], test_docs[view])
            eval_duration = '%.1f' % eval_elapsed()
            best_indicator = ' '
            if err <= best_error[view][name][0]:
                best_error[view][name] = (err, alpha)
                best_indicator = '*' 
            print("%s%f : %i passes : %s-%s %ss %ss" % (best_indicator, err, epoch + 1, view, name, duration, eval_duration))

            if ((epoch + 1) % 5) == 0 or epoch == 0:
                eval_duration = ''
                with elapsed_timer() as eval_elapsed:
                    infer_err, err_count, test_count, predictor = error_rate_for_model(train_model, train_docs[view], test_docs[view], infer=True)
                eval_duration = '%.1f' % eval_elapsed()
                best_indicator = ' '
                if infer_err < best_error[view][name + '_inferred'][0]:
                    best_error[view][name + '_inferred'] = (infer_err, alpha)
                    best_indicator = '*'
                print("%s%f : %i passes : %s-%s %ss %ss" % (best_indicator, infer_err, epoch + 1, view, name + '_inferred', duration, eval_duration))

        print('completed pass %i at alpha %f' % (epoch + 1, alpha))
        alpha -= alpha_delta

    print("END %s" % str(datetime.datetime.now()))
# Out:
# Started.
# ======== view1 =========
# START 2015-12-09 09:44:11.092925
# *0.488636 : 1 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.500000 : 1 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
# *0.545455 : 1 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.500000 : 1 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 1 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.500000 : 1 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 1 passes : view1-dbow+dmm 0.0s 0.0s
# *0.250000 : 1 passes : view1-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 1 passes : view1-dbow+dmc 0.0s 0.0s
# *0.375000 : 1 passes : view1-dbow+dmc_inferred 0.0s 0.0s
# completed pass 1 at alpha 0.025000
# *0.488636 : 2 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.522727 : 2 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 2 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 2 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 2 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 2 at alpha 0.023800
# *0.477273 : 3 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.534091 : 3 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 3 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 3 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 3 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 3 at alpha 0.022600
# *0.477273 : 4 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.522727 : 4 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 4 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 4 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 4 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 4 at alpha 0.021400
# *0.477273 : 5 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.750000 : 5 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
# *0.500000 : 5 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
#  0.625000 : 5 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 5 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.500000 : 5 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 5 passes : view1-dbow+dmm 0.0s 0.0s
#  0.375000 : 5 passes : view1-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 5 passes : view1-dbow+dmc 0.0s 0.0s
# *0.125000 : 5 passes : view1-dbow+dmc_inferred 0.0s 0.0s
# completed pass 5 at alpha 0.020200
# *0.477273 : 6 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.522727 : 6 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 6 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 6 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 6 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 6 at alpha 0.019000
# *0.465909 : 7 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.534091 : 7 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 7 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 7 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 7 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 7 at alpha 0.017800
# *0.454545 : 8 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.511364 : 8 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 8 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 8 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 8 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 8 at alpha 0.016600
# *0.454545 : 9 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.511364 : 9 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 9 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 9 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 9 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 9 at alpha 0.015400
# *0.454545 : 10 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.625000 : 10 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
# *0.488636 : 10 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.375000 : 10 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 10 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.625000 : 10 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 10 passes : view1-dbow+dmm 0.0s 0.0s
#  0.500000 : 10 passes : view1-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 10 passes : view1-dbow+dmc 0.0s 0.0s
#  0.750000 : 10 passes : view1-dbow+dmc_inferred 0.0s 0.0s
# completed pass 10 at alpha 0.014200
# *0.454545 : 11 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.522727 : 11 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 11 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 11 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 11 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 11 at alpha 0.013000
# *0.454545 : 12 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.500000 : 12 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 12 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 12 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 12 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 12 at alpha 0.011800
# *0.454545 : 13 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.511364 : 13 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 13 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 13 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 13 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 13 at alpha 0.010600
# *0.454545 : 14 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.511364 : 14 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 14 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 14 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 14 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 14 at alpha 0.009400
# *0.454545 : 15 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.250000 : 15 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
#  0.511364 : 15 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
#  0.500000 : 15 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 15 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.500000 : 15 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 15 passes : view1-dbow+dmm 0.0s 0.0s
#  0.750000 : 15 passes : view1-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 15 passes : view1-dbow+dmc 0.0s 0.0s
#  0.625000 : 15 passes : view1-dbow+dmc_inferred 0.0s 0.0s
# completed pass 15 at alpha 0.008200
# *0.454545 : 16 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.534091 : 16 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 16 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 16 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 16 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 16 at alpha 0.007000
# *0.454545 : 17 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.522727 : 17 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 17 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 17 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 17 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 17 at alpha 0.005800
# *0.454545 : 18 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.522727 : 18 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 18 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 18 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 18 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 18 at alpha 0.004600
# *0.454545 : 19 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.522727 : 19 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 19 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 19 passes : view1-dbow+dmm 0.0s 0.0s
# *0.477273 : 19 passes : view1-dbow+dmc 0.0s 0.0s
# completed pass 19 at alpha 0.003400
# *0.454545 : 20 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.500000 : 20 passes : view1-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
#  0.522727 : 20 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
#  0.750000 : 20 passes : view1-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 20 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.625000 : 20 passes : view1-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 20 passes : view1-dbow+dmm 0.0s 0.0s
#  0.625000 : 20 passes : view1-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 20 passes : view1-dbow+dmc 0.0s 0.0s
#  0.625000 : 20 passes : view1-dbow+dmc_inferred 0.0s 0.0s
# completed pass 20 at alpha 0.002200
# END 2015-12-09 09:44:14.742157
# ======== view2 =========
# START 2015-12-09 09:44:14.742209
# *0.488636 : 1 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.500000 : 1 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
# *0.500000 : 1 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.750000 : 1 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 1 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.500000 : 1 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 1 passes : view2-dbow+dmm 0.0s 0.0s
# *0.500000 : 1 passes : view2-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 1 passes : view2-dbow+dmc 0.0s 0.0s
# *0.750000 : 1 passes : view2-dbow+dmc_inferred 0.0s 0.0s
# completed pass 1 at alpha 0.025000
# *0.488636 : 2 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.500000 : 2 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 2 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 2 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 2 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 2 at alpha 0.023800
# *0.488636 : 3 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.488636 : 3 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 3 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 3 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 3 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 3 at alpha 0.022600
# *0.477273 : 4 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.1s 0.0s
# *0.488636 : 4 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 4 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 4 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 4 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 4 at alpha 0.021400
#  0.488636 : 5 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.625000 : 5 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
#  0.500000 : 5 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.500000 : 5 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 5 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.625000 : 5 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 5 passes : view2-dbow+dmm 0.0s 0.0s
#  0.625000 : 5 passes : view2-dbow+dmm_inferred 0.0s 0.1s
# *0.477273 : 5 passes : view2-dbow+dmc 0.0s 0.0s
# *0.500000 : 5 passes : view2-dbow+dmc_inferred 0.0s 0.0s
# completed pass 5 at alpha 0.020200
#  0.488636 : 6 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.488636 : 6 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 6 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 6 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 6 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 6 at alpha 0.019000
# *0.477273 : 7 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.488636 : 7 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 7 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 7 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 7 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 7 at alpha 0.017800
#  0.488636 : 8 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.488636 : 8 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 8 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 8 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 8 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 8 at alpha 0.016600
#  0.500000 : 9 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.488636 : 9 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 9 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 9 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 9 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 9 at alpha 0.015400
#  0.488636 : 10 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.750000 : 10 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
# *0.488636 : 10 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
#  0.750000 : 10 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 10 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.500000 : 10 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 10 passes : view2-dbow+dmm 0.0s 0.0s
# *0.250000 : 10 passes : view2-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 10 passes : view2-dbow+dmc 0.0s 0.0s
# *0.375000 : 10 passes : view2-dbow+dmc_inferred 0.0s 0.0s
# completed pass 10 at alpha 0.014200
# *0.477273 : 11 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 11 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 11 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 11 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 11 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 11 at alpha 0.013000
# *0.477273 : 12 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 12 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 12 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 12 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 12 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 12 at alpha 0.011800
# *0.477273 : 13 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 13 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 13 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 13 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 13 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 13 at alpha 0.010600
# *0.477273 : 14 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 14 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 14 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 14 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 14 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 14 at alpha 0.009400
# *0.477273 : 15 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.250000 : 15 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 15 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.250000 : 15 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 15 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.625000 : 15 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 15 passes : view2-dbow+dmm 0.0s 0.0s
#  0.500000 : 15 passes : view2-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 15 passes : view2-dbow+dmc 0.0s 0.0s
#  0.500000 : 15 passes : view2-dbow+dmc_inferred 0.0s 0.0s
# completed pass 15 at alpha 0.008200
# *0.477273 : 16 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 16 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 16 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 16 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 16 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 16 at alpha 0.007000
# *0.477273 : 17 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 17 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 17 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 17 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 17 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 17 at alpha 0.005800
# *0.477273 : 18 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 18 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 18 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 18 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 18 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 18 at alpha 0.004600
# *0.477273 : 19 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
# *0.477273 : 19 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
# *0.477273 : 19 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
# *0.477273 : 19 passes : view2-dbow+dmm 0.0s 0.0s
# *0.477273 : 19 passes : view2-dbow+dmc 0.0s 0.0s
# completed pass 19 at alpha 0.003400
#  0.488636 : 20 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4) 0.0s 0.0s
#  0.625000 : 20 passes : view2-Doc2Vec(dm/c,d100,n5,w3,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 20 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4) 0.0s 0.0s
#  0.500000 : 20 passes : view2-Doc2Vec(dbow,d100,n5,mc5,t4)_inferred 0.0s 0.0s
# *0.477273 : 20 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4) 0.0s 0.0s
#  0.625000 : 20 passes : view2-Doc2Vec(dm/m,d100,n5,w3,mc2,t4)_inferred 0.0s 0.0s
# *0.477273 : 20 passes : view2-dbow+dmm 0.0s 0.0s
#  0.375000 : 20 passes : view2-dbow+dmm_inferred 0.0s 0.0s
# *0.477273 : 20 passes : view2-dbow+dmc 0.0s 0.0s
#  0.625000 : 20 passes : view2-dbow+dmc_inferred 0.0s 0.0s
# completed pass 20 at alpha 0.002200
# END 2015-12-09 09:44:18.680230

# %%
for view in [v1, v2]:
    print '========= %s ========' %view
    for rate, alpha, name in sorted((rate, alpha, name) for name, (rate, alpha) in best_error[view].items()):
        print("%f %s %f" % (rate, name, alpha))
# Out:
# ========= view1 ========
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-64dcece718b7> in <module>()
#       2     print '========= %s ========' %view
#       3     for rate, alpha, name in sorted((rate, alpha, name) for name, (rate, alpha) in best_error[view].items()):
# ----> 4         print("%f %s" % (rate, name, alpha))
#
# TypeError: not all arguments converted during string formatting

# %%
print doc_list['view1'][0]
print '\n', simple_models['view1'][0].docvecs[alldocs['view1'][0].tags[0]]
print '\n', doc_list['view2'][0]
print '\n', simple_models['view2'][0].docvecs[alldocs['view2'][0].tags[0]]
#print '\n\n', doc_list['view2'][:10]
# Out:
# SentimentDocument(words=u'at work, running around like crazy! we be BUSY!\n', tags=[259], split='train', sentiment=1)
#
# [ 0.00514853 -0.04997624  0.06811047 -0.03180665 -0.01680654  0.14893104
#   0.01763977 -0.07546499  0.01179081 -0.06108077  0.02612465 -0.08328539
#   0.00734314 -0.06581231  0.01212456 -0.19955979  0.05103784  0.06782258
#  -0.03058622 -0.10309964  0.08270516 -0.0029613   0.19989891 -0.0581574
#  -0.03992247 -0.06394912 -0.15579315 -0.0613977   0.03092592 -0.12681849
#  -0.07591827  0.09429046  0.06041682  0.07328099 -0.05059278 -0.0148337
#   0.03638268 -0.01616611 -0.11419502 -0.08497099  0.05004817  0.04739601
#   0.02501046  0.01063698  0.02423424  0.04735725  0.07020184  0.00882047
#  -0.00362639  0.05782245  0.00240158  0.10036104  0.06919857  0.02533311
#   0.09578922  0.05706789  0.07535045 -0.03796051  0.03027442 -0.07194908
#  -0.0053239   0.02350993  0.00891548 -0.11736379 -0.08332615 -0.03051617
#   0.03125338 -0.01311546  0.09760806 -0.01401266 -0.04339596  0.04883702
#  -0.04859371 -0.0595874  -0.01479988 -0.01274338  0.11780281  0.00212556
#   0.00515656 -0.00673507  0.05268607  0.06922827 -0.03499911 -0.05349317
#  -0.04309856 -0.03142172 -0.00400522 -0.0296449   0.06960277  0.11400897
#  -0.01550555  0.0422345  -0.03672067  0.04827694  0.0846578   0.06852964
#  -0.02577386  0.05611676  0.02813343  0.03701007]
#
# SentimentDocument(words=u'is hoping that her week from hell ends with a good weekend...\n', tags=[87], split='train', sentiment=-1)
#
# [ 0.04531846 -0.00579319  0.01844292  0.01311583 -0.00634587  0.1628038
#  -0.02961866 -0.0510258  -0.08955771 -0.02681964 -0.01487882  0.08436479
#   0.24372414 -0.16676591 -0.1011582   0.15159066 -0.10951692  0.01439879
#  -0.06687627  0.00861146 -0.04982633 -0.0479822   0.00734912 -0.04374179
#  -0.08652404 -0.21630825 -0.12619746 -0.0710284   0.0761921  -0.1977905
#  -0.16963439  0.03469602 -0.04124192  0.07937863 -0.09526965 -0.00100114
#   0.17765205  0.07055381 -0.0278174  -0.14974226 -0.16785248  0.12494926
#   0.22283126  0.02934532  0.08741666 -0.05335384 -0.05727791 -0.02729696
#  -0.04759474  0.10000598  0.01026385  0.13787678 -0.05015846  0.01355128
#  -0.27422646 -0.11406388  0.09139948 -0.04912325  0.10672867 -0.01727258
#  -0.01669154 -0.0758038   0.02161928 -0.06651147 -0.07079709 -0.06954195
#   0.1694209   0.04514287  0.19817531 -0.16418242  0.21587345 -0.22219017
#  -0.14931482  0.00308288  0.09008201 -0.02450152 -0.19768479 -0.01581643
#  -0.08217119 -0.08024081 -0.01742305  0.15070099 -0.09882105 -0.05630404
#  -0.06800068 -0.12388459 -0.0371902   0.08370399  0.22226547 -0.03779716
#   0.13412602 -0.17257209  0.01512781  0.12420724 -0.04353695  0.10416056
#   0.02526784  0.02407993  0.05961983 -0.13322306]

# %%
doc_id = np.random.randint(simple_models[0].docvecs.count)  # pick random doc; re-run cell for more examples
print('for doc %d...' % doc_id)
for model in simple_models:
    inferred_docvec = model.infer_vector(alldocs[doc_id].words)
    print('%s:\n %s' % (model, model.docvecs.most_similar([inferred_docvec], topn=3)))
